# %% [markdown]
# <a href="https://colab.research.google.com/github/VINAYSKG/Analysis-with-Python/blob/main/Brownwall_food_pvt_ltd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('/content/BROWNWALL TEST FILE.xlsx')
print(df)
# Out:
#      Inquiry No           Timestamp                  Company  \
# 0           102 2024-04-20 00:00:00                  aleMbIc
# 1           104 2025-12-11 15:37:51   FORtuNe seLECT eXOtIca
# 2           105 2024-03-19 00:00:00         zIFaRm  PInNAcLe
# 3           107 2024-03-20 00:00:00         ziFARM  PInnAcle
# 4           121 2025-07-05 11:50:22            EMcurE PhArMA
# ..          ...                 ...                      ...
# 294         340 2024-07-04 00:00:00                INNoVCarE
# 295         448 2024-05-15 00:00:00                  lUPiN
# 296         341 2024-07-04 00:00:00                InnoVcAre
# 297         450 2024-05-15 00:00:00                   LUpiN
# 298         451 2024-12-23 00:00:00                jK  LAxmI
#
#             Contact Name   Category  \
# 0    AstHa MaDam dIv-peT  PHARMA ‎
# 1          devpRAsaD das  PHARMA ‎
# 2           abDUL BaSIt   PHARMA ‎
# 3            ABdUl basit  PHARMA ‎
# 4         aditYA tHAKuR   PHARMA ‎
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Inquiry No          299 non-null    int64
#  1   Timestamp           299 non-null    datetime64[ns]
#  2   Company             299 non-null    object
#  3   Contact Name        297 non-null    object
#  4   Category            298 non-null    object
#  5   Details             177 non-null    object
#  6   Lead Source         240 non-null    object
#  7   Sales Stage         299 non-null    object
#  8   Update Remarks      234 non-null    object
#  9   Next Steps          223 non-null    object
#  10  Next Followup Date  210 non-null    datetime64[ns]
#  11  Budget              252 non-null    float64
#  12  Quantity            186 non-null    object
#  13  Est Order Value     267 non-null    object
#  14  Sales Person Name   299 non-null    object
# ...

# %%
df.head(10)
# Out:
#    Inquiry No           Timestamp                  Company  \
# 0         102 2024-04-20 00:00:00                  aleMbIc
# 1         104 2025-12-11 15:37:51   FORtuNe seLECT eXOtIca
# 2         105 2024-03-19 00:00:00         zIFaRm  PInNAcLe
# 3         107 2024-03-20 00:00:00         ziFARM  PInnAcle
# 4         121 2025-07-05 11:50:22            EMcurE PhArMA
# 5         122 2024-04-20 00:00:00                   hETERO
# 6         123 2024-05-18 00:00:00                  tORrenT
# 7         124 2025-07-05 11:50:31                  tORRent
# 8         125 2024-07-04 00:00:00                inNdicamE
# 9         126 2024-05-18 00:00:00    arIStO  -  vr  GLoBAL
#
#           Contact Name   Category  \
# 0  AstHa MaDam dIv-peT  PHARMA ‎
# 1        devpRAsaD das  PHARMA ‎
# 2         abDUL BaSIt   PHARMA ‎
# 3          ABdUl basit  PHARMA ‎
# 4       aditYA tHAKuR   PHARMA ‎
# 5               ReeNa   PHARMA ‎
# 6              nILeSH   PHARMA ‎
# 7             raksHiTa  PHARMA ‎
# ...

# %%
df.isnull()
# Out:
#      Inquiry No  Timestamp  Company  Contact Name  Category  Details  \
# 0         False      False    False         False     False     True
# 1         False      False    False         False     False    False
# 2         False      False    False         False     False     True
# 3         False      False    False         False     False     True
# 4         False      False    False         False     False    False
# ..          ...        ...      ...           ...       ...      ...
# 294       False      False    False         False     False    False
# 295       False      False    False         False     False     True
# 296       False      False    False         False     False    False
# 297       False      False    False         False     False     True
# 298       False      False    False         False     False    False
#
#      Lead Source  Sales Stage  Update Remarks  Next Steps  ...  Budget  \
# ...

# %%
df.isnull().sum()
# Out:
# Inquiry No              0
# Timestamp               0
# Company                 0
# Contact Name            2
# Category                1
# Details               122
# Lead Source            59
# Sales Stage             0
# Update Remarks         65
# Next Steps             76
# Next Followup Date     89
# Budget                 47
# Quantity              113
# Est Order Value        32
# Sales Person Name       0
# OCCASSION               3
# LOCATION               24
# Inquiry Type            0
# 2nd Owner             119
# Back Office           123
# 1st Owner               1
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype == 'O':
        if df[col].isnull().any():
            df[col].fillna(df[col].mode()[0], inplace=True)
    else:
        if df[col].isnull().any():
            df[col].fillna(df[col].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Inquiry No            0
# Timestamp             0
# Company               0
# Contact Name          0
# Category              0
# Details               0
# Lead Source           0
# Sales Stage           0
# Update Remarks        0
# Next Steps            0
# Next Followup Date    0
# Budget                0
# Quantity              0
# Est Order Value       0
# Sales Person Name     0
# OCCASSION             0
# LOCATION              0
# Inquiry Type          0
# 2nd Owner             0
# Back Office           0
# 1st Owner             0
# dtype: int64

# %%
df.head(5)
# Out:
#    Inquiry No           Timestamp                  Company  \
# 0         102 2024-04-20 00:00:00                  aleMbIc
# 1         104 2025-12-11 15:37:51   FORtuNe seLECT eXOtIca
# 2         105 2024-03-19 00:00:00         zIFaRm  PInNAcLe
# 3         107 2024-03-20 00:00:00         ziFARM  PInnAcle
# 4         121 2025-07-05 11:50:22            EMcurE PhArMA
#
#           Contact Name   Category            Details Lead Source  \
# 0  AstHa MaDam dIv-peT  PHARMA ‎             Unknown     Calling
# 1        devpRAsaD das  PHARMA ‎        indent raise     Calling
# 2         abDUL BaSIt   PHARMA ‎             Unknown     Calling
# 3          ABdUl basit  PHARMA ‎             Unknown     Calling
# 4       aditYA tHAKuR   PHARMA ‎   Will let you know   ONE 2 ONE
#
#         Sales Stage Update Remarks         Next Steps  ...  Budget  Quantity  \
# 0              Dead        Unknown     Arrange Sample  ...   300.0    3000.0
# ...

# %%
df.tail(5)
# Out:
#      Inquiry No  Timestamp      Company       Contact Name   Category  \
# 294         340 2024-07-04    INNoVCarE           asHUTosh  PHARMA ‎
# 295         448 2024-05-15      lUPiN      NIdHi  PATkar    PHARMA ‎
# 296         341 2024-07-04    InnoVcAre            ShUbhAm  PHARMA ‎
# 297         450 2024-05-15       LUpiN     mAhesH  agArwaL  PHARMA ‎
# 298         451 2024-12-23    jK  LAxmI             TUShAr  CORPORATE
#
#                                         Details Lead Source Sales Stage  \
# 294  LBL Set of 2 dark chocolate Period related   One 2 One   Order WON
# 295                                     Unknown     Calling        Dead
# 296                   Need few options on veins   One 2 One        Dead
# 297                                     Unknown     Calling        Dead
# 298                    Instant Neembu Pani Cups     Calling        Dead
#
#             Update Remarks        Next Steps  ...        Budget     Quantity  \
# ...

# %%
df.to_excel("cleandata.xlsx", index=False)
